# %% [markdown]
# <a href="https://colab.research.google.com/github/thinh2904/huhu/blob/master/thinh_pro_max.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import os

# %% [markdown]
# 1 Tải 1 url về

# %%
link=requests.get('https://vietnamnet.vn/vn/thoi-su/quoc-hoi/phat-bieu-cua-chu-tich-qh-tai-cuoc-gap-mat-dbqh-qua-cac-thoi-ky-703465.html')

# %%
link.text
# Out:
# '<!DOCTYPE html><html lang="vi"><head><script language="javascript" src="https://vnn-res.vgcloud.vn/ResV9/js/startup-2019-v003.js">\xa0</script><script type="text/javascript">\n       var globalads_off=false;\n     </script><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><link type="image/x-icon" href="https://vnn-res.vgcloud.vn/ResV9/images/faviconvnn2018.ico" rel="shortcut icon" /><meta name="viewport" content="width=device-width, minimum-scale=0.3, maximum-scale=5, initial-scale=1.0, user-scalable=yes" /><title>Phát biểu của Chủ tịch QH tại cuộc gặp mặt ĐBQH qua các thời kỳ  - VietNamNet\n          </title><meta name="description" content="Toàn văn bài phát biểu của Chủ tịch QH Nguyễn Thị Kim Ngân tại cuộc gặp mặt đại biểu Quốc hội qua các thời kỳ nhân kỷ niệm 75 năm ngày Tổng tuyển cử đầu tiên." /><meta name="keywords" content="Chủ tịch Quốc hội, Nguyễn Thị Kim Ngân" /><meta name="news_keywords" content="Chủ tịch Quốc hội, Nguyễn Thị Kim Ngân" /><meta name="r
# ...

# %%
soup_a = BeautifulSoup(link.text,'html.parser')

# %%
soup_a
# Out:
# <!DOCTYPE html>
# <html lang="vi"><head><script language="javascript" src="https://vnn-res.vgcloud.vn/ResV9/js/startup-2019-v003.js"> </script><script type="text/javascript">
#        var globalads_off=false;
#      </script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><link href="https://vnn-res.vgcloud.vn/ResV9/images/faviconvnn2018.ico" rel="shortcut icon" type="image/x-icon"/><meta content="width=device-width, minimum-scale=0.3, maximum-scale=5, initial-scale=1.0, user-scalable=yes" name="viewport"/><title>Phát biểu của Chủ tịch QH tại cuộc gặp mặt ĐBQH qua các thời kỳ  - VietNamNet
# ...

# %% [markdown]
# 2. Lưu 1 html vào thư mục chỉ định

# %%
file = 'tao_deptrai' + '.txt'
f = open(file, 'w')
f.write(link.text)    #Nhập nội dung file
f.close()

# %% [markdown]
# 3. Cách lấy 1 phần tử đầu tiên ra khỏi list và xóa nó khỏi list

# %%
l = ['a','b','c','d']
print('CHuỗi trước khi edit:',l)
x = l.pop(0)
print('Phần tử đầu tiên:',x)
print('Chuỗi sau khi edit:',l)
# Out:
# CHuỗi trước khi edit: ['a', 'b', 'c', 'd']
# Phần tử đầu tiên: a
# Chuỗi sau khi edit: ['b', 'c', 'd']

# %% [markdown]
# 4. Cách lấy các url trong html

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /
# https://vietnamnet.vn/vn/thoi-su/dai-hoi-dang-lan-thu-xiii/
# #
# /vn/tin-moi-nong/
# /vn/tin-tuc-24h/
# https://www.facebook.com/vietnamnet.vn
# https://www.youtube.com/vietnamnetofficial
# javascript:void(0)
# javascript:void(0)
# https://id.vietnamnet.vn/Home.html
# javascript:void(0)
# /
# /vn/thoi-su/chinh-tri/
# /vn/talkshow/
# /vn/thoi-su/
# /vn/thoi-su/chong-tham-nhung/
# /vn/thoi-su/quoc-hoi/
# /vn/thoi-su/an-toan-giao-thong/
# /vn/thoi-su/moi-truong/
# /vn/thoi-su/clip-nong/
# /vn/thoi-su/bhxh-bhyt/
# /vn/thoi-su/quoc-phong/
# /vn/kinh-doanh/
# /vn/kinh-doanh/tai-chinh/
# /vn/kinh-doanh/dau-tu/
# /vn/kinh-doanh/thi-truong/
# /vn/kinh-doanh/doanh-nhan/
# /vn/kinh-doanh/tu-van-tai-chinh/
# /vn/kinh-doanh/Amaccao/
# /vn/giai-tri/
# /vn/giai-tri/the-gioi-sao/
# /vn/giai-tri/thoi-trang/
# /vn/giai-tri/nhac/
# /vn/giai-tri/phim/
# /vn/giai-tri/truyen-hinh/
# /vn/giai-tri/sach/
# /vn/giai-tri/di-san-my-thuat-san-khau/
# /vn/the-gioi/
# /vn/the-gioi/binh-luan-quoc-te/
# ...
